# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d87ad102-daea-4728-936c-a69ea15f0175" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d87ad102-daea-4728-936c-a69ea15f0175">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].median())

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts().plot(kind='bar')
plt.title('Customer Churn Distribution')
plt.show()

# %%
pd.crosstab(df['Contract'], df['Churn'])
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
pd.crosstab(df['Contract'], df['Churn']).plot(kind='bar')
plt.title('Contract Type vs Churn')
plt.show()

# %%
df.groupby('Churn')['tenure'].mean()
# Out:
# Churn
# No     37.569965
# Yes    17.979133
# Name: tenure, dtype: float64

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
pd.crosstab(df['InternetService'], df['Churn'])
# Out:
# Churn              No   Yes
# InternetService
# DSL              1962   459
# Fiber optic      1799  1297
# No               1413   113

# %%
pd.crosstab(df['InternetService'], df['Churn']).plot(kind='bar')
plt.title('Internet Service vs Churn')
plt.show()

# %%
pd.crosstab(df['PaymentMethod'], df['Churn'])
# Out:
# Churn                        No   Yes
# PaymentMethod
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308

# %%
pd.crosstab(df['PaymentMethod'], df['Churn']).plot(kind='bar', figsize=(8,5))
plt.title('Payment Method vs Churn')
plt.show()

# %% [markdown]
# Customer Churn Analysis
#
# Key Findings:
# 1. Customers with month-to-month contracts have the highest churn.
# 2. Customers with shorter tenure are more likely to leave.
# 3. Higher monthly charges are associated with increased churn.
# 4. Certain payment methods show higher churn rates.
# 5. Internet service type influences customer retention.
#
# Recommendations:
# 1. Offer discounts for long-term contracts.
# 2. Improve onboarding for new customers.
# 3. Introduce loyalty rewards programs.
# 4. Provide personalized retention offers.
# 5. Improve customer support and engagement.
